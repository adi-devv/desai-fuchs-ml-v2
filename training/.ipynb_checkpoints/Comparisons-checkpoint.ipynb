# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
noises = np.linspace(0, 30, 7, dtype=int)
models = ['gpr', 'svr', 'nn']
colors = ['g', 'b', 'r']
energies = ['Maximum', 'Total', 'Average']
energies_abbrev = ['max', 'tot', 'avg']
modelLineStyles = ['solid', 'dotted', 'dashdot']
train_points = np.linspace(500, 20000, 40, dtype=int)
label_font = 28
legend_font = 16
tick_font = 20
if not os.path.exists('plots'):
    os.mkdir('plots')

dfs = np.array([[None]*7 for i in range(3)])

for i, model in enumerate(models):
    for j, noise in enumerate(noises):
        dfs[i, j] = pd.read_csv(f'results/{model}_noise-{noise}/metrics.csv')
display(dfs[0,0].head())
# Out:
#    train_points  gpu_memory      time  train_mse_max  train_mse_tot  \
# 0           500    1.250203  6.087369       0.000029   7.450780e+11
# 1          1000    1.278849  6.332433       0.000021   4.280335e+12
# 2          1500    1.305542  6.523179       0.000026   5.018594e+12
# 3          2000    1.407756  7.666398       0.000018   4.393041e+12
# 4          2500    1.469604  7.696648       0.000050   3.032414e+12
#
#    train_mse_avg  test_mse_noisy_max  test_mse_noisy_tot  test_mse_noisy_avg  \
# 0   4.328929e-07            0.000013        6.630791e+11        3.899166e-07
# 1   1.102722e-06            0.000039        4.787234e+12        1.433011e-06
# 2   4.103057e-07            0.000035        3.470104e+12        6.640030e-07
# 3   9.496168e-07            0.000009        3.918459e+12        7.460727e-07
# 4   1.388610e-06            0.000031        2.229467e+12        1.126194e-06
#
#    test_mse_exact_max  ...  train_mape_avg  test_mape_noisy_max  \
# 0            0.000013  ...        0.008166             0.014362
# 1            0.000039  ...        0.010880             0.014663
# 2            0.000035  ...        0.007038             0.013721
# 3            0.000009  ...        0.008386             0.006553
# 4            0.000031  ...        0.011116             0.011682
#
#    test_mape_noisy_tot  test_mape_noisy_avg  test_mape_exact_max  \
# 0             0.013605             0.008911             0.014362
# 1             0.018848             0.011328             0.014663
# 2             0.015418             0.007021             0.013721
# 3             0.015079             0.008025             0.006553
# 4             0.011774             0.011069             0.011682
#
#    test_mape_exact_tot  test_mape_exact_avg  test_mape_exact_uncorrected_max  \
# 0             0.013605             0.008911                         0.014357
# 1             0.018848             0.011328                         0.014642
# 2             0.015418             0.007021                         0.013705
# 3             0.015079             0.008025                         0.006676
# 4             0.011774             0.011069                         0.012520
#
#    test_mape_exact_uncorrected_tot  test_mape_exact_uncorrected_avg
# 0                         0.013610                         0.008911
# 1                         0.018800                         0.011290
# 2                         0.015368                         0.007023
# 3                         0.015019                         0.008042
# 4                         0.011701                         0.011183
#
# [5 rows x 24 columns]

# %% [markdown]
# # Training Time

# %%
fig, ax = plt.subplots(figsize=(7, 6))
for i, model in enumerate(models):
    times = np.mean(np.array([dfs[i, j]['time'] for j in range(7)]), axis=0)
    ax.plot(dfs[i, j]['train_points'], times, c=colors[i], linestyle = modelLineStyles[i], label=model.upper())
ax.legend(fontsize=20, loc='upper left')
ax.grid()
ax.set_xticks([0, 5000, 10000, 15000, 20000])
ax.set_xticklabels([0, 5000, 10000, 15000, 20000], fontsize=tick_font)
ax.set_yticks([0, 10, 20, 30, 40])#, 125, 150, 175, 200])
ax.set_yticklabels([0, 10, 20, 30, 40], fontsize=tick_font)
ax.set_xlim([0, 20000])
ax.set_xlabel('Number of Training Points', fontsize=tick_font)
ax.set_ylabel('Training Time (s)', fontsize=tick_font)
fig.savefig('plots/time.png')

# %% [markdown]
# # GPU Memory Consumption

# %%
noise = noises[j]
fig, ax = plt.subplots(figsize=(7, 6))
for i, model in enumerate(models):
    times = np.mean(np.array([dfs[i, j]['gpu_memory'] for j in range(7)]), axis=0)
    ax.plot(dfs[i, j]['train_points'], times, c=colors[i], linestyle = modelLineStyles[i], label=model.upper())
ax.legend(fontsize=20, loc='upper left')
ax.grid()
ax.set_xticks([0, 5000, 10000, 15000, 20000])
ax.set_xticklabels([0, 5000, 10000, 15000, 20000], fontsize=tick_font)
ax.set_yticks([0, 4, 8, 12, 16])
ax.set_yticklabels([0, 4, 8, 12, 16], fontsize=tick_font)
ax.set_xlim([0, 20000])
ax.set_xlabel('Number of Training Points', fontsize=tick_font)
ax.set_ylabel('GPU Memory (GiB)', fontsize=tick_font)
fig.savefig('plots/gpu_mem.png')

# %% [markdown]
# # Testing MAPE

# %%
j = 6
noise = noises[j]
fig, ax = plt.subplots(ncols=3, figsize=(20, 6))
for k, energy in enumerate(energies_abbrev):
    for i, model in enumerate(models):
        #ax[k].plot(dfs[i, j]['train_points'], dfs[i, j][f'test_mape_noisy_{energy}']*100, c=colors[i], linestyle = modelLineStyles[0], label=model.upper() + ' ' + energy)
        ax[k].plot(dfs[i, j]['train_points'], dfs[i, j][f'test_mape_exact_{energy}']*100, c=colors[i], linestyle = modelLineStyles[1], label=model.upper() + ' ' + energy)
    ax[k].legend(fontsize=20, loc='upper right')
    ax[k].grid()
    ax[k].set_xticks([0, 5000, 10000, 15000, 20000])
    ax[k].set_xticklabels([0, 5000, 10000, 15000, 20000], fontsize=tick_font)
    ax[k].set_xlim([0, 20000])
    ax[k].set_xlabel('Number of Training Points', fontsize=tick_font)
    ax[k].set_yticks(np.arange(0, 11, 2, dtype=int))
    ax[k].set_yticklabels(np.arange(0, 11, 2, dtype=int), fontsize=tick_font)
    ax[k].set_ylabel('MAPE (%)', fontsize=tick_font)
fig.savefig('plots/test_mape_noise=' + str(noise) + '.png')

# %% [markdown]
# # MAPE v Noise

# %%
point_idx = 39
fig, ax = plt.subplots(ncols=3, figsize=(20, 6))
for k, energy in enumerate(energies_abbrev):
    for i, model in enumerate(models):
        y1 = [dfs[i, j][f'test_mape_noisy_{energy}'][point_idx]*100 for j in range(7)]
        y2 = [dfs[i, j][f'test_mape_exact_{energy}'][point_idx]*100 for j in range(7)]
        ax[k].plot(noises, y1, c=colors[i], linestyle = modelLineStyles[0], label=model.upper() + ' ' + energy)
        ax[k].plot(noises, y2, c=colors[i], linestyle = modelLineStyles[1], label=model.upper() + ' ' + energy)
        #ax[k].plot(dfs[i, j]['train_points'], dfs[i, j][f'test_mape_exact_{energy}']*100, c=colors[i], linestyle = modelLineStyles[i], label=model.upper() + ' ' + energy)
        #ax[k].plot(dfs[i, j]['train_points'], dfs[i, j][f'test_mape_noisy_{energy}']*100, c=colors[i], linestyle = modelLineStyles[i], label=model.upper() + ' ' + energy)
    ax[k].legend(fontsize=20, loc='upper left')
    ax[k].grid()
    ax[k].set_ylim([0, 30])
    ax[k].set_xlim([0, 30])
    ax[k].set_xlabel('Noise Level (%)', fontsize=tick_font)
    ax[k].set_xticks(noises[0:])
    ax[k].set_xticklabels(noises[0:], fontsize=tick_font)
    ax[k].set_yticks(noises)
    ax[k].set_yticklabels(noises[0:], fontsize=tick_font)
    ax[k].set_ylabel('MAPE (%)', fontsize=tick_font)
ax[1].set_title(f'points = {train_points[point_idx]}', fontsize=label_font)
fig.savefig('plots/test_mape_points=' + str(round(train_points[point_idx]/1000)) + 'k.png')

# %% [markdown]
# # RMSE vs Noise

# %%
point_idx = 39
fig, ax = plt.subplots(ncols=3, figsize=(20, 6))
ylims = [0.1, 18e6, 0.018]
for k, energy in enumerate(energies_abbrev):
    for i, model in enumerate(models):
        y1 = [np.sqrt(dfs[i, j][f'test_mse_noisy_{energy}'][point_idx]) for j in range(7)]
        y2 = [np.sqrt(dfs[i, j][f'test_mse_exact_{energy}'][point_idx]) for j in range(7)]
        ax[k].plot(noises, y1, c=colors[i], linestyle = modelLineStyles[0], label=model.upper() + ' ' + energy)
        ax[k].plot(noises, y2, c=colors[i], linestyle = modelLineStyles[1], label=model.upper() + ' ' + energy)
    ax[k].legend(fontsize=20, loc='upper left')
    ax[k].grid()
    ax[k].set_xlim([0, 30])
    ax[k].set_xlabel('Noise Level (%)', fontsize=tick_font)
    ax[k].set_xticks(noises[0:])
    ax[k].set_xticklabels(noises[0:], fontsize=tick_font)
    ax[k].set_ylabel('RMSE (MeV)', fontsize=tick_font)
    ax[k].set_yticks(np.linspace(0, ylims[k], 6))
    ax[k].set_yticklabels('',fontsize=tick_font)
    ax[k].set_ylim([0, ylims[k]])
ax[1].set_title(f'points = {train_points[point_idx]}', fontsize=label_font)
fig.savefig('plots/test_mse_points=' + str(round(train_points[point_idx]/1000)) + 'k.png')

# %% [markdown]
# # Test RMSE 3 Noises

# %%
#Set up ticks for the three energies
maxTicks = np.linspace(0, .100, 6)
totTicks = np.linspace(5e5, 1.8e7, 6)
avgTicks = np.linspace(0, .018, 6)

tickList = [maxTicks, totTicks, avgTicks]

#Special set-up for total energy rmse to ensure format is scientific precision
totTickLabel = []
for tickNum in totTicks:
    aTickLabel = str(tickNum/1e6) + 'e6'
    totTickLabel.append(aTickLabel)
    
tickLabels = [maxTicks, totTickLabel, avgTicks]

#Set up the y-lims for the three energies
maxLim = [0, .110]
totLim = [5e5, 2e7]
avgLim = [0, .02]


limList = [maxLim, totLim, avgLim]
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(28, 7))
ax[0].set_ylabel('RMSE (MeV)', fontsize=label_font)
#Enumerate for each energy
for k, energy in enumerate(energies):
    
    #Manual check for which energy we're plotting.
    test_MSE = None
    exact_MSE = None
    if k == 0:
        test_MSE = max_test_MSE
        exact_MSE = max_exact_MSE
    elif k == 1:
        test_MSE = tot_test_MSE
        exact_MSE = tot_exact_MSE
    elif k == 2:
        test_MSE = avg_test_MSE
        exact_MSE = avg_exact_MSE
        
    #Now to plot the models
    for j, noise in enumerate(noises):
        for i, model in enumerate(models):
            if noise %10 == 0 and noise!=0:
                if noise == 10:
                    ax[k].plot(points[:], np.sqrt(test_MSE[i, j][:]), c=colors[i], linestyle = modelLineStyles[i], label=model.upper())
                    if i == 2:
                        ax[k].plot(points, np.sqrt(theor_mse_err[k, j])*np.ones(20), linestyle='dashed', color='black', label='Ideal')
                else:
                    ax[k].plot(points[:], np.sqrt(test_MSE[i, j][:]), c=colors[i],linestyle = modelLineStyles[i])
                    ax[k].plot(points, np.sqrt(theor_mse_err[k, j])*np.ones(20),  linestyle='dashed', color='black')

    ax[k].set_xticks([0, 5000, 10000, 15000, 20000])
    ax[k].set_xticklabels([0, 5000, 10000, 15000, 20000], fontsize=tick_font)
    ax[k].set_yticks(tickList[k])
    ax[k].set_yticklabels(tickLabels[k], fontsize=tick_font)

    ax[k].set_ylim(limList[k])
    ax[k].set_xlim([0, 20000])
    ax[k].set_xlabel('Number of Training Points', fontsize=label_font)
    if k == 2:
        ax[k].legend(bbox_to_anchor = (1.37, 0.6), loc='center right', fontsize = 25)
    ax[k].grid(linewidth = 2.5)

fig.savefig('plots/3_layer_rmse_err_noise=' + str(noise)+ '.png', bbox_inches = "tight")

# %% [markdown]
# # GPU Memory Used

# %%
for j, noise in enumerate(noises):
    fig, ax = plt.subplots(figsize=(7, 6))
    for i, model in enumerate(models):
        ax.plot(points[:], mem_used[i, j][:], c=colors[i], linestyle = modelLineStyles[i], label=model.upper())
    ax.legend(fontsize=legend_font)
    ax.grid()
    ax.set_xticks([0, 5000, 10000, 15000, 20000])
    ax.set_xticklabels([0, 5000, 10000, 15000, 20000], fontsize=tick_font)
    ax.set_yticks([0, 2, 4, 6, 8, 10, 12])#, 125, 150, 175, 200])
    ax.set_yticklabels([0, 2, 4, 6, 8, 10, 12], fontsize=tick_font)
    ax.set_xlim([0, 20000])
    ax.set_xlabel('Number of Training Points', fontsize=label_font)
    ax.set_ylabel('GPU Memory (GiB)', fontsize=label_font)
    fig.savefig('plots/memGPU_noise=' + str(noise) + '.png')
